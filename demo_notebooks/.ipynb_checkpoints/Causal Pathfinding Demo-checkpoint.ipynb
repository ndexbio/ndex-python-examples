# %% [markdown]
# Import Python Modules

# %%
# %matplotlib inline
from ndex.networkn import NdexGraph
import ndex.beta.toolbox as toolbox
from causal_paths import causal_utilities as cu
import networkx as nx
import matplotlib.pyplot as plt

def plot_ndex_graph(network):
    nx.draw(network, network.pos, labels=nx.get_node_attributes(network,'name'))
    plt.show()

# %% [markdown]
# Setup NDEx Connection Configuration

# %%
ndex_server = "http://public.ndexbio.org"
rm_username="test"
rm_password="test"

# %% [markdown]
# Download the desired reference network

# %%
# Get the RAS machine
network_id='50e3dff7-133e-11e6-a039-06603eb7f303'
G = NdexGraph(server=ndex_server, uuid=network_id, username=rm_username, password=rm_password)
print G.get_name()
# Out:
# The RAS Machine

# %% [markdown]
# HUMAN: “Inhibition of EGFR downregulated MEK phosphorylation”
#
# BOB: new observation = decreased EGFR (source) -> decreased MAP2K1 and MAP2K2 (targets) phosphorylation

# %%
# Compute the source-target network
P1 = cu.get_source_target_network(G, ['EGFR'], ['MAP2K1', 'MAP2K2'], "EGFR to MAP2K1 and MAP2K2", npaths=20)
# Out:
# Created EGFR to MAP2K1 and MAP2K2

# %%
# Apply a layout
toolbox.apply_source_target_layout(P1)
# Out:
# {1024: {'st_layout': 'Forward', 'name': u'ARAF'}, 386: {'st_layout': 'Reverse', 'name': u'bsk'}, 5379: {'st_layout': 'Forward', 'name': u'selumetinib'}, 17924: {'st_layout': 'Reverse', 'name': u'SHC1'}, 4103: {'st_layout': 'Forward', 'name': u'KSR1'}, 28296: {'st_layout': 'Reverse', 'name': u'SOS1'}, 1419: {'st_layout': 'Forward', 'name': u'MET'}, 8451: {'st_layout': 'Reverse', 'name': u'HDAC6'}, 2068: {'st_layout': 'Forward', 'name': u'Raf_MEK_ERK'}, 277: {'st_layout': 'Reverse', 'name': u'MEK'}, 26: {'st_layout': 'Reverse', 'name': u'TP53'}, 6429: {'st_layout': 'Target', 'name': u'MAP2K2'}, 3614: {'st_layout': 'Reverse', 'name': u'MAPK1'}, 304: {'st_layout': 'Reverse', 'name': u'cell_death'}, 5167: {'st_layout': 'Forward', 'name': u'Ras'}, 2736: {'st_layout': 'Forward', 'name': u'EGF'}, 1073: {'st_layout': 'Reverse', 'name': u'progesterone'}, 573: {'st_layout': 'Reverse', 'name': u'pkbA'}, 698: {'st_layout': 'Forward', 'name': u'cisplatin'}, 317: {'st_layout': 'Both', 'name': u'EPHB2'}, 461: {'st_layout': 'Both', 'name': u'ERK1_2'}, 4691: {'st_layout': 'Target', 'name': u'MAP2K1'}, 6869: {'st_layout': 'Forward', 'name': u'PAK1'}, 1754: {'st_layout': 'Reverse', 'name': u'PIK3CA'}, 58: {'st_layout': 'Reverse', 'name': u'cell_proliferation'}, 606: {'st_layout': 'Both', 'name': u'BRAF'}, 224: {'st_layout': 'Forward', 'name': u'ERBB2'}, 10978: {'st_layout': 'Reverse', 'name': u'ARCN1'}, 1254: {'st_layout': 'Forward', 'name': u'ESR1'}, 233: {'st_layout': 'Source', 'name': u'EGFR'}, 9327: {'st_layout': 'Reverse', 'name': u'IRS1'}, 4848: {'st_layout': 'Forward', 'name': u'U0126'}, 1783: {'st_layout': 'Both', 'name': u'RAF1'}, 762: {'st_layout': 'Reverse', 'name': u'VEGFA'}, 767: {'st_layout': 'Both', 'name': u'MAPK3'}}

# %%
plot_ndex_graph(P1)

# %%
# Apply a cytoscape style from a template network
template_id = '4f53171c-600f-11e6-b0a6-06603eb7f303'
toolbox.apply_template(P1, template_id)

# %%
# Save to NDEx in the drh account
P1.upload_to(ndex_server, 'drh', 'drh')

# %% [markdown]
# HUMAN: "We mutated MAP2K1 at serine 25 and observed decreased phosphorylation of MMP9"
#
# BOB: new observation = mutation of MAP2K1 (source) -> decreased MMP9 (target) phosphorylation

# %%
# Compute the source-target network
P2 = cu.get_source_target_network(G, ['MAP2K1'], ['MMP9'], "MAP2K1 to MMP9", npaths=20)

# %%
# Apply a layout
toolbox.apply_source_target_layout(P2)

# %%
# Apply a cytoscape style from a template network
template_id = '4f53171c-600f-11e6-b0a6-06603eb7f303'
toolbox.apply_template(P2, template_id)

# %%
# Save to NDEx in the drh account
P2.upload_to(ndex_server, 'drh', 'drh')
